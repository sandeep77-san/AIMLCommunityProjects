# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# C:\Users\insapab\.conda\envs\AIMachine\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\insapab\.conda\envs\AIMachine\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\insapab\.conda\envs\AIMachine\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\insapab\.conda\envs\AIMachine\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\insapab\.conda\envs\AIMachine\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\insapab\.conda\envs\AIMachine\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
csv_reader = pd.read_csv(r'C:\Users\insapab\Desktop\Python\Projects\Deep Learning based fall-detection\Week4\dataset_new.csv')

# %%
csv_reader.shape
# Out:
# (46087, 35)

# %%
csv_reader.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46087 entries, 0 to 46086
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   nose_xCoord           46087 non-null  float64
#  1   nose_yCoord           46087 non-null  float64
#  2   leftEye_xCoord        46087 non-null  float64
#  3   leftEye_yCoord        46087 non-null  float64
#  4   rightEye_xCoord       46087 non-null  float64
#  5   rightEye_yCoord       46087 non-null  float64
#  6   leftEar_xCoord        46087 non-null  float64
#  7   leftEar_yCoord        46087 non-null  float64
#  8   rightEar_xCoord       46087 non-null  float64
#  9   rightEar_yCoord       46087 non-null  float64
#  10  leftShoulder_xCoord   46087 non-null  float64
#  11  leftShoulder_yCoord   46087 non-null  float64
#  12  rightShoulder_xCoord  46087 non-null  float64
#  13  rightShoulder_yCoord  46087 non-null  float64
#  14  leftElbow_xCoord      46087 non-null  float64
#  15  leftElbow_yCoord      46087 non-null  float64
#  16  rightElbow_xCoord     46087 non-null  float64
#  17  rightElbow_yCoord     46087 non-null  float64
#  18  leftWrist_xCoord      46087 non-null  float64
#  19  leftWrist_yCoord      46087 non-null  float64
#  20  rightWrist_xCoord     46087 non-null  float64
#  21  rightWrist_yCoord     46087 non-null  float64
#  22  leftHip_xCoord        46087 non-null  float64
#  23  leftHip_yCoord        46087 non-null  float64
#  24  rightHip_xCoord       46087 non-null  float64
#  25  rightHip_yCoord       46087 non-null  float64
#  26  leftKnee_xCoord       46087 non-null  float64
#  27  leftKnee_yCoord       46087 non-null  float64
#  28  rightKnee_xCoord      46087 non-null  float64
#  29  rightKnee_yCoord      46087 non-null  float64
#  30  leftAnkle_xCoord      46087 non-null  float64
#  31  leftAnkle_yCoord      46087 non-null  float64
#  32  rightAnkle_xCoord     46087 non-null  float64
#  33  rightAnkle_yCoord     46087 non-null  float64
#  34  action                46087 non-null  object
# dtypes: float64(34), object(1)
# memory usage: 12.3+ MB

# %%
csv_reader.isnull().sum()
# Out:
# nose_xCoord             0
# nose_yCoord             0
# leftEye_xCoord          0
# leftEye_yCoord          0
# rightEye_xCoord         0
# rightEye_yCoord         0
# leftEar_xCoord          0
# leftEar_yCoord          0
# rightEar_xCoord         0
# rightEar_yCoord         0
# leftShoulder_xCoord     0
# leftShoulder_yCoord     0
# rightShoulder_xCoord    0
# rightShoulder_yCoord    0
# leftElbow_xCoord        0
# leftElbow_yCoord        0
# rightElbow_xCoord       0
# rightElbow_yCoord       0
# leftWrist_xCoord        0
# leftWrist_yCoord        0
# rightWrist_xCoord       0
# rightWrist_yCoord       0
# leftHip_xCoord          0
# leftHip_yCoord          0
# rightHip_xCoord         0
# rightHip_yCoord         0
# leftKnee_xCoord         0
# leftKnee_yCoord         0
# rightKnee_xCoord        0
# rightKnee_yCoord        0
# leftAnkle_xCoord        0
# leftAnkle_yCoord        0
# rightAnkle_xCoord       0
# rightAnkle_yCoord       0
# action                  0
# dtype: int64

# %%
csv_reader.head()
# Out:
#    nose_xCoord  nose_yCoord  leftEye_xCoord  leftEye_yCoord  rightEye_xCoord  \
# 0    56.190699   296.234485       47.495736      304.506221        47.426405
# 1    58.070928   294.830473       50.438684      303.459697        50.413592
# 2    60.347484   293.276433       52.336790      302.564670        51.749057
# 3    60.354865   293.306309       52.357229      302.583683        51.762654
# 4    65.561807   293.525188       56.037613      300.768831        57.071169
#
#    rightEye_yCoord  leftEar_xCoord  leftEar_yCoord  rightEar_xCoord  \
# 0       290.856178       54.045254      317.089020        51.259983
# 1       289.433166       53.729076      316.393431        54.849626
# 2       286.061810       55.336751      314.123402        56.071776
# 3       286.115169       55.277190      314.167158        56.112637
# 4       285.863794       57.981080      313.506743        58.160196
#
#    rightEar_yCoord  leftShoulder_xCoord  leftShoulder_yCoord  \
# 0       284.022411            98.719044           335.695742
# 1       285.199219            93.755129           332.737840
# 2       283.196761            99.536148           335.110901
# 3       283.222878            99.445646           335.118755
# 4       281.245576           100.224719           332.374132
#
#    rightShoulder_xCoord  rightShoulder_yCoord  leftElbow_xCoord  \
# 0            100.930659            276.349225        157.444074
# 1             98.838978            276.021288        157.410591
# 2             98.860682            274.606000        158.371219
# 3             98.875438            274.704609        158.187421
# 4            100.049734            274.107841        159.574954
#
#    leftElbow_yCoord  rightElbow_xCoord  rightElbow_yCoord  leftWrist_xCoord  \
# 0        355.579856         160.055622         263.549644        211.092471
# 1        355.818210         160.001528         263.775434        210.561140
# 2        355.589284         160.047945         263.605888        212.588271
# 3        355.583027         160.002901         263.667578        212.520676
# 4        355.690267         159.897382         264.676454        215.138463
#
#    leftWrist_yCoord  rightWrist_xCoord  rightWrist_yCoord  leftHip_xCoord  \
# 0        340.496882         211.716219         265.121970      206.776064
# 1        340.941379         213.042795         265.595944      207.230442
# 2        340.294056         213.446340         265.688338      207.995333
# 3        340.506925         213.198046         265.694996      208.177199
# 4        339.589972         213.799203         266.681833      209.853354
#
#    leftHip_yCoord  rightHip_xCoord  rightHip_yCoord  leftKnee_xCoord  \
# 0      326.265427       206.764836       283.173980       298.463096
# 1      326.509203       206.469197       285.407934       296.631039
# 2      326.541586       206.597968       285.700611       296.139735
# 3      326.640903       206.658796       285.600408       296.232999
# 4      325.764535       206.813333       286.422076       296.605081
#
#    leftKnee_yCoord  rightKnee_xCoord  rightKnee_yCoord  leftAnkle_xCoord  \
# 0       327.059039        293.699426        291.596869        365.788908
# 1       327.641395        295.514859        288.871951        366.269758
# 2       327.478825        296.085122        288.846652        365.683480
# 3       327.496065        296.276140        288.761548        365.609956
# 4       327.646756        295.789608        288.276175        364.847562
#
#    leftAnkle_yCoord  rightAnkle_xCoord  rightAnkle_yCoord   action
# 0        335.774955         361.338563         295.586793  Sitting
# 1        335.466869         361.195325         295.577829  Sitting
# 2        335.637860         361.131568         295.322548  Sitting
# 3        335.688486         361.174033         295.351302  Sitting
# 4        335.984524         360.887404         295.336077  Sitting

# %%
csv_reader['action'].value_counts()
# Out:
# Walking    17352
# Sitting    11635
# Pushups    10470
# Falling     6630
# Name: action, dtype: int64

# %%
Sitting = csv_reader[csv_reader['action']=='Sitting'].head(6630).copy()
Pushups = csv_reader[csv_reader['action']=='Pushups'].head(6630).copy()
Walking = csv_reader[csv_reader['action']=='Walking'].head(6630).copy()
Falling = csv_reader[csv_reader['action']=='Falling'].head(6630).copy()
balance_data =  pd.DataFrame()
balance_data =  balance_data.append([Sitting, Pushups, Walking, Falling])
balance_data.shape
# Out:
# (26520, 35)

# %%
balance_data['action'].value_counts()
# Out:
# Sitting    6630
# Walking    6630
# Pushups    6630
# Falling    6630
# Name: action, dtype: int64

# %%
balance_data.head()
# Out:
#    nose_xCoord  nose_yCoord  leftEye_xCoord  leftEye_yCoord  rightEye_xCoord  \
# 0    56.190699   296.234485       47.495736      304.506221        47.426405
# 1    58.070928   294.830473       50.438684      303.459697        50.413592
# 2    60.347484   293.276433       52.336790      302.564670        51.749057
# 3    60.354865   293.306309       52.357229      302.583683        51.762654
# 4    65.561807   293.525188       56.037613      300.768831        57.071169
#
#    rightEye_yCoord  leftEar_xCoord  leftEar_yCoord  rightEar_xCoord  \
# 0       290.856178       54.045254      317.089020        51.259983
# 1       289.433166       53.729076      316.393431        54.849626
# 2       286.061810       55.336751      314.123402        56.071776
# 3       286.115169       55.277190      314.167158        56.112637
# 4       285.863794       57.981080      313.506743        58.160196
#
#    rightEar_yCoord  leftShoulder_xCoord  leftShoulder_yCoord  \
# 0       284.022411            98.719044           335.695742
# 1       285.199219            93.755129           332.737840
# 2       283.196761            99.536148           335.110901
# 3       283.222878            99.445646           335.118755
# 4       281.245576           100.224719           332.374132
#
#    rightShoulder_xCoord  rightShoulder_yCoord  leftElbow_xCoord  \
# 0            100.930659            276.349225        157.444074
# 1             98.838978            276.021288        157.410591
# 2             98.860682            274.606000        158.371219
# 3             98.875438            274.704609        158.187421
# 4            100.049734            274.107841        159.574954
#
#    leftElbow_yCoord  rightElbow_xCoord  rightElbow_yCoord  leftWrist_xCoord  \
# 0        355.579856         160.055622         263.549644        211.092471
# 1        355.818210         160.001528         263.775434        210.561140
# 2        355.589284         160.047945         263.605888        212.588271
# 3        355.583027         160.002901         263.667578        212.520676
# 4        355.690267         159.897382         264.676454        215.138463
#
#    leftWrist_yCoord  rightWrist_xCoord  rightWrist_yCoord  leftHip_xCoord  \
# 0        340.496882         211.716219         265.121970      206.776064
# 1        340.941379         213.042795         265.595944      207.230442
# 2        340.294056         213.446340         265.688338      207.995333
# 3        340.506925         213.198046         265.694996      208.177199
# 4        339.589972         213.799203         266.681833      209.853354
#
#    leftHip_yCoord  rightHip_xCoord  rightHip_yCoord  leftKnee_xCoord  \
# 0      326.265427       206.764836       283.173980       298.463096
# 1      326.509203       206.469197       285.407934       296.631039
# 2      326.541586       206.597968       285.700611       296.139735
# 3      326.640903       206.658796       285.600408       296.232999
# 4      325.764535       206.813333       286.422076       296.605081
#
#    leftKnee_yCoord  rightKnee_xCoord  rightKnee_yCoord  leftAnkle_xCoord  \
# 0       327.059039        293.699426        291.596869        365.788908
# 1       327.641395        295.514859        288.871951        366.269758
# 2       327.478825        296.085122        288.846652        365.683480
# 3       327.496065        296.276140        288.761548        365.609956
# 4       327.646756        295.789608        288.276175        364.847562
#
#    leftAnkle_yCoord  rightAnkle_xCoord  rightAnkle_yCoord   action
# 0        335.774955         361.338563         295.586793  Sitting
# 1        335.466869         361.195325         295.577829  Sitting
# 2        335.637860         361.131568         295.322548  Sitting
# 3        335.688486         361.174033         295.351302  Sitting
# 4        335.984524         360.887404         295.336077  Sitting

# %%
## check for correlation between input features variables 
balance_data_corr = balance_data.corr(method="pearson")
balance_data_corr_decision = balance_data_corr.applymap(str) 
for i in range(balance_data_corr.shape[0]):
    for j in range(balance_data_corr.shape[1]):
        if abs(balance_data_corr.iloc[i][j]) <= 0.1:
            balance_data_corr_decision.replace(balance_data_corr_decision.iloc[i][j], 'weak', inplace = True)
        elif abs(balance_data_corr.iloc[i][j]) >= 0.9:
            balance_data_corr_decision.replace(balance_data_corr_decision.iloc[i][j], 'Strong', inplace = True)
        else:
            balance_data_corr_decision.replace(balance_data_corr_decision.iloc[i][j], 'Normal', inplace = True)
balance_data_corr_decision
# Out:
#                      nose_xCoord nose_yCoord leftEye_xCoord leftEye_yCoord  \
# nose_xCoord               Strong      Normal         Strong         Normal
# nose_yCoord               Normal      Strong         Normal         Strong
# leftEye_xCoord            Strong      Normal         Strong         Normal
# leftEye_yCoord            Normal      Strong         Normal         Strong
# rightEye_xCoord           Strong      Normal         Strong         Normal
# rightEye_yCoord           Normal      Strong         Normal         Strong
# leftEar_xCoord            Strong      Normal         Strong         Normal
# leftEar_yCoord            Normal      Strong         Normal         Strong
# rightEar_xCoord           Strong      Normal         Strong         Normal
# rightEar_yCoord           Normal      Strong         Normal         Strong
# leftShoulder_xCoord       Strong      Normal         Strong         Normal
# leftShoulder_yCoord       Normal      Strong         Normal         Strong
# rightShoulder_xCoord      Strong      Normal         Strong         Normal
# rightShoulder_yCoord      Normal      Strong         Normal         Strong
# leftElbow_xCoord          Strong      Normal         Strong         Normal
# leftElbow_yCoord          Normal      Normal         Normal         Normal
# rightElbow_xCoord         Normal      Normal         Normal         Normal
# rightElbow_yCoord         Normal      Normal         Normal         Normal
# leftWrist_xCoord          Normal      Normal         Normal         Normal
# leftWrist_yCoord          Normal      Normal         Normal         Normal
# rightWrist_xCoord         Normal      Normal         Normal         Normal
# rightWrist_yCoord         Normal      Normal         Normal         Normal
# leftHip_xCoord            Normal      Normal         Normal         Normal
# leftHip_yCoord            Normal      Normal         Normal         Normal
# rightHip_xCoord           Normal      Normal         Normal         Normal
# rightHip_yCoord           Normal      Normal         Normal         Normal
# leftKnee_xCoord           Normal      Normal         Normal         Normal
# leftKnee_yCoord           Normal      Normal         Normal         Normal
# rightKnee_xCoord          Normal      Normal         Normal         Normal
# rightKnee_yCoord          Normal      Normal         Normal         Normal
# leftAnkle_xCoord          Normal      Normal         Normal         Normal
# leftAnkle_yCoord          Normal      Normal         Normal         Normal
# rightAnkle_xCoord         Normal      Normal         Normal         Normal
# rightAnkle_yCoord         Normal      Normal         Normal         Normal
#
#                      rightEye_xCoord rightEye_yCoord leftEar_xCoord  \
# nose_xCoord                   Strong          Normal         Strong
# nose_yCoord                   Normal          Strong         Normal
# leftEye_xCoord                Strong          Normal         Strong
# leftEye_yCoord                Normal          Strong         Normal
# rightEye_xCoord               Strong          Normal         Strong
# rightEye_yCoord               Normal          Strong         Normal
# leftEar_xCoord                Strong          Normal         Strong
# leftEar_yCoord                Normal          Strong         Normal
# rightEar_xCoord               Strong          Normal         Strong
# rightEar_yCoord               Normal          Strong         Normal
# leftShoulder_xCoord           Strong          Normal         Strong
# leftShoulder_yCoord           Normal          Strong         Normal
# rightShoulder_xCoord          Strong          Normal         Strong
# rightShoulder_yCoord          Normal          Strong         Normal
# leftElbow_xCoord              Strong          Normal         Strong
# leftElbow_yCoord              Normal          Normal         Normal
# rightElbow_xCoord             Normal          Normal         Normal
# rightElbow_yCoord             Normal          Normal         Normal
# leftWrist_xCoord              Normal          Normal         Normal
# leftWrist_yCoord              Normal          Normal         Normal
# rightWrist_xCoord             Normal          Normal         Normal
# rightWrist_yCoord             Normal          Normal         Normal
# leftHip_xCoord                Normal          Normal         Normal
# leftHip_yCoord                Normal          Normal         Normal
# rightHip_xCoord               Normal          Normal         Normal
# rightHip_yCoord               Normal          Normal         Normal
# leftKnee_xCoord               Normal          Normal         Normal
# leftKnee_yCoord               Normal          Normal         Normal
# rightKnee_xCoord              Normal          Normal         Normal
# rightKnee_yCoord              Normal          Normal         Normal
# leftAnkle_xCoord              Normal          Normal         Normal
# leftAnkle_yCoord              Normal          Normal         Normal
# rightAnkle_xCoord             Normal          Normal         Normal
# rightAnkle_yCoord             Normal          Normal         Normal
#
#                      leftEar_yCoord rightEar_xCoord rightEar_yCoord  \
# nose_xCoord                  Normal          Strong          Normal
# nose_yCoord                  Strong          Normal          Strong
# leftEye_xCoord               Normal          Strong          Normal
# leftEye_yCoord               Strong          Normal          Strong
# rightEye_xCoord              Normal          Strong          Normal
# rightEye_yCoord              Strong          Normal          Strong
# leftEar_xCoord               Normal          Strong          Normal
# leftEar_yCoord               Strong          Normal          Strong
# rightEar_xCoord              Normal          Strong          Normal
# rightEar_yCoord              Strong          Normal          Strong
# leftShoulder_xCoord          Normal          Strong          Normal
# leftShoulder_yCoord          Strong          Normal          Strong
# rightShoulder_xCoord         Normal          Strong          Normal
# rightShoulder_yCoord         Strong          Normal          Strong
# leftElbow_xCoord             Normal          Strong          Normal
# leftElbow_yCoord             Strong          Normal          Normal
# rightElbow_xCoord            Normal          Normal          Normal
# rightElbow_yCoord            Normal          Normal          Normal
# leftWrist_xCoord             Normal          Normal          Normal
# leftWrist_yCoord             Normal          Normal          Normal
# rightWrist_xCoord            Normal          Normal          Normal
# rightWrist_yCoord            Normal          Normal          Normal
# leftHip_xCoord               Normal          Normal          Normal
# leftHip_yCoord               Normal          Normal          Normal
# rightHip_xCoord              Normal          Normal          Normal
# rightHip_yCoord              Normal          Normal          Normal
# leftKnee_xCoord              Normal          Normal          Normal
# leftKnee_yCoord              Normal          Normal          Normal
# rightKnee_xCoord             Normal          Normal          Normal
# rightKnee_yCoord             Normal          Normal          Normal
# leftAnkle_xCoord             Normal          Normal          Normal
# leftAnkle_yCoord             Normal          Normal          Normal
# rightAnkle_xCoord            Normal          Normal          Normal
# rightAnkle_yCoord            Normal          Normal          Normal
#
#                      leftShoulder_xCoord leftShoulder_yCoord  \
# nose_xCoord                       Strong              Normal
# nose_yCoord                       Normal              Strong
# leftEye_xCoord                    Strong              Normal
# leftEye_yCoord                    Normal              Strong
# rightEye_xCoord                   Strong              Normal
# rightEye_yCoord                   Normal              Strong
# leftEar_xCoord                    Strong              Normal
# leftEar_yCoord                    Normal              Strong
# rightEar_xCoord                   Strong              Normal
# rightEar_yCoord                   Normal              Strong
# leftShoulder_xCoord               Strong              Normal
# leftShoulder_yCoord               Normal              Strong
# rightShoulder_xCoord              Strong              Normal
# rightShoulder_yCoord              Normal              Strong
# leftElbow_xCoord                  Strong              Normal
# leftElbow_yCoord                  Normal              Strong
# rightElbow_xCoord                 Strong              Normal
# rightElbow_yCoord                 Normal              Strong
# leftWrist_xCoord                  Normal              Normal
# leftWrist_yCoord                  Normal              Strong
# rightWrist_xCoord                 Normal              Normal
# rightWrist_yCoord                 Normal              Strong
# leftHip_xCoord                    Strong              Normal
# leftHip_yCoord                    Normal              Normal
# rightHip_xCoord                   Normal              Normal
# rightHip_yCoord                   Normal              Normal
# leftKnee_xCoord                   Normal              Normal
# leftKnee_yCoord                   Normal              Normal
# rightKnee_xCoord                  Normal              Normal
# rightKnee_yCoord                  Normal              Normal
# leftAnkle_xCoord                  Normal              Normal
# leftAnkle_yCoord                  Normal              Normal
# rightAnkle_xCoord                 Normal              Normal
# rightAnkle_yCoord                 Normal              Normal
#
#                      rightShoulder_xCoord rightShoulder_yCoord  \
# nose_xCoord                        Strong               Normal
# nose_yCoord                        Normal               Strong
# leftEye_xCoord                     Strong               Normal
# leftEye_yCoord                     Normal               Strong
# rightEye_xCoord                    Strong               Normal
# rightEye_yCoord                    Normal               Strong
# leftEar_xCoord                     Strong               Normal
# leftEar_yCoord                     Normal               Strong
# rightEar_xCoord                    Strong               Normal
# rightEar_yCoord                    Normal               Strong
# leftShoulder_xCoord                Strong               Normal
# leftShoulder_yCoord                Normal               Strong
# rightShoulder_xCoord               Strong               Normal
# rightShoulder_yCoord               Normal               Strong
# leftElbow_xCoord                   Strong               Normal
# leftElbow_yCoord                   Normal               Strong
# rightElbow_xCoord                  Strong               Normal
# rightElbow_yCoord                  Normal               Strong
# leftWrist_xCoord                   Normal               Normal
# leftWrist_yCoord                   Normal               Normal
# rightWrist_xCoord                  Normal               Normal
# rightWrist_yCoord                  Normal               Strong
# leftHip_xCoord                     Strong               Normal
# leftHip_yCoord                     Normal               Normal
# rightHip_xCoord                    Strong               Normal
# rightHip_yCoord                    Normal               Normal
# leftKnee_xCoord                    Normal               Normal
# leftKnee_yCoord                    Normal               Normal
# rightKnee_xCoord                   Normal               Normal
# rightKnee_yCoord                   Normal               Normal
# leftAnkle_xCoord                   Normal               Normal
# leftAnkle_yCoord                   Normal               Normal
# rightAnkle_xCoord                  Normal               Normal
# rightAnkle_yCoord                  Normal               Normal
#
#                      leftElbow_xCoord leftElbow_yCoord rightElbow_xCoord  \
# nose_xCoord                    Strong           Normal            Normal
# nose_yCoord                    Normal           Normal            Normal
# leftEye_xCoord                 Strong           Normal            Normal
# leftEye_yCoord                 Normal           Normal            Normal
# rightEye_xCoord                Strong           Normal            Normal
# rightEye_yCoord                Normal           Normal            Normal
# leftEar_xCoord                 Strong           Normal            Normal
# leftEar_yCoord                 Normal           Strong            Normal
# rightEar_xCoord                Strong           Normal            Normal
# rightEar_yCoord                Normal           Normal            Normal
# leftShoulder_xCoord            Strong           Normal            Strong
# leftShoulder_yCoord            Normal           Strong            Normal
# rightShoulder_xCoord           Strong           Normal            Strong
# rightShoulder_yCoord           Normal           Strong            Normal
# leftElbow_xCoord               Strong           Normal            Strong
# leftElbow_yCoord               Normal           Strong            Normal
# rightElbow_xCoord              Strong           Normal            Strong
# rightElbow_yCoord              Normal           Strong            Normal
# leftWrist_xCoord               Strong           Normal            Strong
# leftWrist_yCoord               Normal           Strong            Normal
# rightWrist_xCoord              Strong           Normal            Strong
# rightWrist_yCoord              Normal           Normal            Normal
# leftHip_xCoord                 Strong           Normal            Strong
# leftHip_yCoord                 Normal           Strong            Normal
# rightHip_xCoord                Strong           Normal            Strong
# rightHip_yCoord                Normal           Normal            Normal
# leftKnee_xCoord                Normal           Normal            Normal
# leftKnee_yCoord                Normal           Normal            Normal
# rightKnee_xCoord               Normal           Normal            Normal
# rightKnee_yCoord               Normal           Normal            Normal
# leftAnkle_xCoord               Normal           Normal            Normal
# leftAnkle_yCoord               Normal           Normal            Normal
# rightAnkle_xCoord              Normal           Normal            Normal
# rightAnkle_yCoord              Normal           Normal            Normal
#
#                      rightElbow_yCoord leftWrist_xCoord leftWrist_yCoord  \
# nose_xCoord                     Normal           Normal           Normal
# nose_yCoord                     Normal           Normal           Normal
# leftEye_xCoord                  Normal           Normal           Normal
# leftEye_yCoord                  Normal           Normal           Normal
# rightEye_xCoord                 Normal           Normal           Normal
# rightEye_yCoord                 Normal           Normal           Normal
# leftEar_xCoord                  Normal           Normal           Normal
# leftEar_yCoord                  Normal           Normal           Normal
# rightEar_xCoord                 Normal           Normal           Normal
# rightEar_yCoord                 Normal           Normal           Normal
# leftShoulder_xCoord             Normal           Normal           Normal
# leftShoulder_yCoord             Strong           Normal           Strong
# rightShoulder_xCoord            Normal           Normal           Normal
# rightShoulder_yCoord            Strong           Normal           Normal
# leftElbow_xCoord                Normal           Strong           Normal
# leftElbow_yCoord                Strong           Normal           Strong
# rightElbow_xCoord               Normal           Strong           Normal
# rightElbow_yCoord               Strong           Normal           Normal
# leftWrist_xCoord                Normal           Strong           Normal
# leftWrist_yCoord                Normal           Normal           Strong
# rightWrist_xCoord               Normal           Strong           Normal
# rightWrist_yCoord               Strong           Normal           Normal
# leftHip_xCoord                  Normal           Normal           Normal
# leftHip_yCoord                  Strong           Normal           Normal
# rightHip_xCoord                 Normal           Normal           Normal
# rightHip_yCoord                 Strong           Normal           Normal
# leftKnee_xCoord                 Normal           Normal           Normal
# leftKnee_yCoord                 Normal           Normal           Normal
# rightKnee_xCoord                Normal           Normal           Normal
# rightKnee_yCoord                Normal           Normal           Normal
# leftAnkle_xCoord                Normal           Normal           Normal
# leftAnkle_yCoord                Normal           Normal           Normal
# rightAnkle_xCoord               Normal           Normal           Normal
# rightAnkle_yCoord               Normal           Normal           Normal
#
#                      rightWrist_xCoord rightWrist_yCoord leftHip_xCoord  \
# nose_xCoord                     Normal            Normal         Normal
# nose_yCoord                     Normal            Normal         Normal
# leftEye_xCoord                  Normal            Normal         Normal
# leftEye_yCoord                  Normal            Normal         Normal
# rightEye_xCoord                 Normal            Normal         Normal
# rightEye_yCoord                 Normal            Normal         Normal
# leftEar_xCoord                  Normal            Normal         Normal
# leftEar_yCoord                  Normal            Normal         Normal
# rightEar_xCoord                 Normal            Normal         Normal
# rightEar_yCoord                 Normal            Normal         Normal
# leftShoulder_xCoord             Normal            Normal         Strong
# leftShoulder_yCoord             Normal            Strong         Normal
# rightShoulder_xCoord            Normal            Normal         Strong
# rightShoulder_yCoord            Normal            Strong         Normal
# leftElbow_xCoord                Strong            Normal         Strong
# leftElbow_yCoord                Normal            Normal         Normal
# rightElbow_xCoord               Strong            Normal         Strong
# rightElbow_yCoord               Normal            Strong         Normal
# leftWrist_xCoord                Strong            Normal         Normal
# leftWrist_yCoord                Normal            Normal         Normal
# rightWrist_xCoord               Strong            Normal         Normal
# rightWrist_yCoord               Normal            Strong         Normal
# leftHip_xCoord                  Normal            Normal         Strong
# leftHip_yCoord                  Normal            Normal         Normal
# rightHip_xCoord                 Normal            Normal         Strong
# rightHip_yCoord                 Normal            Normal         Normal
# leftKnee_xCoord                 Normal            Normal         Strong
# leftKnee_yCoord                 Normal            Normal         Normal
# rightKnee_xCoord                Normal            Normal         Strong
# rightKnee_yCoord                Normal            Normal         Normal
# leftAnkle_xCoord                Normal            Normal         Normal
# leftAnkle_yCoord                Normal            Normal         Normal
# rightAnkle_xCoord               Normal            Normal         Normal
# rightAnkle_yCoord               Normal            Normal         Normal
#
#                      leftHip_yCoord rightHip_xCoord rightHip_yCoord  \
# nose_xCoord                  Normal          Normal          Normal
# nose_yCoord                  Normal          Normal          Normal
# leftEye_xCoord               Normal          Normal          Normal
# leftEye_yCoord               Normal          Normal          Normal
# rightEye_xCoord              Normal          Normal          Normal
# rightEye_yCoord              Normal          Normal          Normal
# leftEar_xCoord               Normal          Normal          Normal
# leftEar_yCoord               Normal          Normal          Normal
# rightEar_xCoord              Normal          Normal          Normal
# rightEar_yCoord              Normal          Normal          Normal
# leftShoulder_xCoord          Normal          Normal          Normal
# leftShoulder_yCoord          Normal          Normal          Normal
# rightShoulder_xCoord         Normal          Strong          Normal
# rightShoulder_yCoord         Normal          Normal          Normal
# leftElbow_xCoord             Normal          Strong          Normal
# leftElbow_yCoord             Strong          Normal          Normal
# rightElbow_xCoord            Normal          Strong          Normal
# rightElbow_yCoord            Strong          Normal          Strong
# leftWrist_xCoord             Normal          Normal          Normal
# leftWrist_yCoord             Normal          Normal          Normal
# rightWrist_xCoord            Normal          Normal          Normal
# rightWrist_yCoord            Normal          Normal          Normal
# leftHip_xCoord               Normal          Strong          Normal
# leftHip_yCoord               Strong          Normal          Strong
# rightHip_xCoord              Normal          Strong          Normal
# rightHip_yCoord              Strong          Normal          Strong
# leftKnee_xCoord              Normal          Strong          Normal
# leftKnee_yCoord              Strong          Normal          Strong
# rightKnee_xCoord             Normal          Strong          Normal
# rightKnee_yCoord             Strong          Normal          Strong
# leftAnkle_xCoord             Normal          Normal          Normal
# leftAnkle_yCoord             Strong          Normal          Normal
# rightAnkle_xCoord            Normal          Normal          Normal
# rightAnkle_yCoord            Normal          Normal          Normal
#
#                      leftKnee_xCoord leftKnee_yCoord rightKnee_xCoord  \
# nose_xCoord                   Normal          Normal           Normal
# nose_yCoord                   Normal          Normal           Normal
# leftEye_xCoord                Normal          Normal           Normal
# leftEye_yCoord                Normal          Normal           Normal
# rightEye_xCoord               Normal          Normal           Normal
# rightEye_yCoord               Normal          Normal           Normal
# leftEar_xCoord                Normal          Normal           Normal
# leftEar_yCoord                Normal          Normal           Normal
# rightEar_xCoord               Normal          Normal           Normal
# rightEar_yCoord               Normal          Normal           Normal
# leftShoulder_xCoord           Normal          Normal           Normal
# leftShoulder_yCoord           Normal          Normal           Normal
# rightShoulder_xCoord          Normal          Normal           Normal
# rightShoulder_yCoord          Normal          Normal           Normal
# leftElbow_xCoord              Normal          Normal           Normal
# leftElbow_yCoord              Normal          Normal           Normal
# rightElbow_xCoord             Normal          Normal           Normal
# rightElbow_yCoord             Normal          Normal           Normal
# leftWrist_xCoord              Normal          Normal           Normal
# leftWrist_yCoord              Normal          Normal           Normal
# rightWrist_xCoord             Normal          Normal           Normal
# rightWrist_yCoord             Normal          Normal           Normal
# leftHip_xCoord                Strong          Normal           Strong
# leftHip_yCoord                Normal          Strong           Normal
# rightHip_xCoord               Strong          Normal           Strong
# rightHip_yCoord               Normal          Strong           Normal
# leftKnee_xCoord               Strong          Normal           Strong
# leftKnee_yCoord               Normal          Strong           Normal
# rightKnee_xCoord              Strong          Normal           Strong
# rightKnee_yCoord              Normal          Strong           Normal
# leftAnkle_xCoord              Strong          Normal           Strong
# leftAnkle_yCoord              Normal          Strong           Normal
# rightAnkle_xCoord             Strong          Normal           Strong
# rightAnkle_yCoord             Normal          Normal           Normal
#
#                      rightKnee_yCoord leftAnkle_xCoord leftAnkle_yCoord  \
# nose_xCoord                    Normal           Normal           Normal
# nose_yCoord                    Normal           Normal           Normal
# leftEye_xCoord                 Normal           Normal           Normal
# leftEye_yCoord                 Normal           Normal           Normal
# rightEye_xCoord                Normal           Normal           Normal
# rightEye_yCoord                Normal           Normal           Normal
# leftEar_xCoord                 Normal           Normal           Normal
# leftEar_yCoord                 Normal           Normal           Normal
# rightEar_xCoord                Normal           Normal           Normal
# rightEar_yCoord                Normal           Normal           Normal
# leftShoulder_xCoord            Normal           Normal           Normal
# leftShoulder_yCoord            Normal           Normal           Normal
# rightShoulder_xCoord           Normal           Normal           Normal
# rightShoulder_yCoord           Normal           Normal           Normal
# leftElbow_xCoord               Normal           Normal           Normal
# leftElbow_yCoord               Normal           Normal           Normal
# rightElbow_xCoord              Normal           Normal           Normal
# rightElbow_yCoord              Normal           Normal           Normal
# leftWrist_xCoord               Normal           Normal           Normal
# leftWrist_yCoord               Normal           Normal           Normal
# rightWrist_xCoord              Normal           Normal           Normal
# rightWrist_yCoord              Normal           Normal           Normal
# leftHip_xCoord                 Normal           Normal           Normal
# leftHip_yCoord                 Strong           Normal           Strong
# rightHip_xCoord                Normal           Normal           Normal
# rightHip_yCoord                Strong           Normal           Normal
# leftKnee_xCoord                Normal           Strong           Normal
# leftKnee_yCoord                Strong           Normal           Strong
# rightKnee_xCoord               Normal           Strong           Normal
# rightKnee_yCoord               Strong           Normal           Strong
# leftAnkle_xCoord               Normal           Strong           Normal
# leftAnkle_yCoord               Strong           Normal           Strong
# rightAnkle_xCoord              Normal           Strong           Normal
# rightAnkle_yCoord              Strong           Normal           Strong
#
#                      rightAnkle_xCoord rightAnkle_yCoord
# nose_xCoord                     Normal            Normal
# nose_yCoord                     Normal            Normal
# leftEye_xCoord                  Normal            Normal
# leftEye_yCoord                  Normal            Normal
# rightEye_xCoord                 Normal            Normal
# rightEye_yCoord                 Normal            Normal
# leftEar_xCoord                  Normal            Normal
# leftEar_yCoord                  Normal            Normal
# rightEar_xCoord                 Normal            Normal
# rightEar_yCoord                 Normal            Normal
# leftShoulder_xCoord             Normal            Normal
# leftShoulder_yCoord             Normal            Normal
# rightShoulder_xCoord            Normal            Normal
# rightShoulder_yCoord            Normal            Normal
# leftElbow_xCoord                Normal            Normal
# leftElbow_yCoord                Normal            Normal
# rightElbow_xCoord               Normal            Normal
# rightElbow_yCoord               Normal            Normal
# leftWrist_xCoord                Normal            Normal
# leftWrist_yCoord                Normal            Normal
# rightWrist_xCoord               Normal            Normal
# rightWrist_yCoord               Normal            Normal
# leftHip_xCoord                  Normal            Normal
# leftHip_yCoord                  Normal            Normal
# rightHip_xCoord                 Normal            Normal
# rightHip_yCoord                 Normal            Normal
# leftKnee_xCoord                 Strong            Normal
# leftKnee_yCoord                 Normal            Normal
# rightKnee_xCoord                Strong            Normal
# rightKnee_yCoord                Normal            Strong
# leftAnkle_xCoord                Strong            Normal
# leftAnkle_yCoord                Normal            Strong
# rightAnkle_xCoord               Strong            Normal
# rightAnkle_yCoord               Normal            Strong

# %%
## only 8 key independent features are identified based on correlation matrix
d ={'nose_xCoord': balance_data['nose_xCoord'], 'nose_yCoord': balance_data['nose_yCoord'], 'leftElbow_yCoord': balance_data['leftElbow_yCoord'], 'rightElbow_xCoord': balance_data['rightElbow_xCoord'], 'rightWrist_yCoord': balance_data['rightWrist_yCoord'], 'rightHip_yCoord': balance_data['rightHip_yCoord'], 'leftKnee_xCoord': balance_data['leftKnee_xCoord'], 'leftAnkle_yCoord': balance_data['leftAnkle_yCoord'], 'action': balance_data['action']}
balance_data =  pd.DataFrame(data=d)
balance_data.head()
# Out:
#    nose_xCoord  nose_yCoord  leftElbow_yCoord  rightElbow_xCoord  \
# 0    56.190699   296.234485        355.579856         160.055622
# 1    58.070928   294.830473        355.818210         160.001528
# 2    60.347484   293.276433        355.589284         160.047945
# 3    60.354865   293.306309        355.583027         160.002901
# 4    65.561807   293.525188        355.690267         159.897382
#
#    rightWrist_yCoord  rightHip_yCoord  leftKnee_xCoord  leftAnkle_yCoord  \
# 0         265.121970       283.173980       298.463096        335.774955
# 1         265.595944       285.407934       296.631039        335.466869
# 2         265.688338       285.700611       296.139735        335.637860
# 3         265.694996       285.600408       296.232999        335.688486
# 4         266.681833       286.422076       296.605081        335.984524
#
#     action
# 0  Sitting
# 1  Sitting
# 2  Sitting
# 3  Sitting
# 4  Sitting

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_Y=LabelEncoder()
balance_data.iloc[:,8]=labelencoder_Y.fit_transform(balance_data.iloc[:,8].values)
balance_data.head()
# Out:
#    nose_xCoord  nose_yCoord  leftElbow_yCoord  rightElbow_xCoord  \
# 0    56.190699   296.234485        355.579856         160.055622
# 1    58.070928   294.830473        355.818210         160.001528
# 2    60.347484   293.276433        355.589284         160.047945
# 3    60.354865   293.306309        355.583027         160.002901
# 4    65.561807   293.525188        355.690267         159.897382
#
#    rightWrist_yCoord  rightHip_yCoord  leftKnee_xCoord  leftAnkle_yCoord  \
# 0         265.121970       283.173980       298.463096        335.774955
# 1         265.595944       285.407934       296.631039        335.466869
# 2         265.688338       285.700611       296.139735        335.637860
# 3         265.694996       285.600408       296.232999        335.688486
# 4         266.681833       286.422076       296.605081        335.984524
#
#    action
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2

# %%
X_Raw=balance_data.iloc[:,0:8].values 
Y_label =balance_data.iloc[:,8].values
X_Raw.shape
# Out:
# (26520, 8)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler() 
X_scaled = sc.fit_transform(X_Raw)

# %%
## making batches of input data of size 120 values with a gap of 30 values
import scipy.stats as stats
X = []
Y = []
buffer_size = 120
shift_size = 30
for i in range(0, (len(X_scaled)-buffer_size), shift_size):
    X_frame = np.zeros((buffer_size,8))
    for j in range(0,8,1):
        X_frame[:,j] = (X_scaled[:,j])[i:i+buffer_size]
    label = stats.mode(Y_label[i:i+buffer_size])[0][0]
    X.append(X_frame)
    Y.append(label)
X = np.asarray(X).reshape(-1,buffer_size,8)
Y = np.asarray(Y)
X.shape,Y.shape
# Out:
# ((880, 120, 8), (880,))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test= train_test_split(X,Y, test_size=0.20, random_state=0)
X_train.shape,X_test.shape,Y_train.shape, Y_test.shape
# Out:
# ((704, 120, 8), (176, 120, 8), (704,), (176,))

# %%
X_train = X_train.reshape(704,120,8,1)
X_test = X_test.reshape(176,120,8,1)
X_train[0].shape,X_test[0].shape
# Out:
# ((120, 8, 1), (120, 8, 1))

# %%
# 2D CNN model
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D
from keras.optimizers import Adam
model = Sequential()
model.add(Conv2D(32, kernel_size=(2, 2), activation='relu',input_shape=X_train[0].shape))
model.add(Dropout(0.1))
model.add(Conv2D(64, kernel_size=(2, 2), activation='relu'))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))
model.compile(optimizer=Adam(lr = 0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy']) 
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 119, 7, 32)        160
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 119, 7, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 118, 6, 64)        8256
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 45312)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                2900032
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 2,908,708
# Trainable params: 2,908,708
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=10, verbose=1)
# Out:
# Train on 704 samples, validate on 176 samples
# Epoch 1/10
# 704/704 [==============================] - 5s 7ms/step - loss: 1.1027 - acc: 0.5625 - val_loss: 0.5487 - val_acc: 0.7841
# Epoch 2/10
# 704/704 [==============================] - 4s 5ms/step - loss: 0.5633 - acc: 0.7670 - val_loss: 0.3059 - val_acc: 0.9091
# Epoch 3/10
# 704/704 [==============================] - 4s 5ms/step - loss: 0.3967 - acc: 0.8423 - val_loss: 0.2936 - val_acc: 0.9091
# Epoch 4/10
# 704/704 [==============================] - 4s 6ms/step - loss: 0.2694 - acc: 0.9020 - val_loss: 0.1818 - val_acc: 0.9545
# Epoch 5/10
# 704/704 [==============================] - 4s 6ms/step - loss: 0.2134 - acc: 0.9304 - val_loss: 0.1834 - val_acc: 0.9318
# Epoch 6/10
# 704/704 [==============================] - 4s 5ms/step - loss: 0.2062 - acc: 0.9247 - val_loss: 0.1651 - val_acc: 0.9489
# Epoch 7/10
# 704/704 [==============================] - 4s 5ms/step - loss: 0.1356 - acc: 0.9588 - val_loss: 0.1881 - val_acc: 0.9261
# Epoch 8/10
# 704/704 [==============================] - 4s 5ms/step - loss: 0.1076 - acc: 0.9616 - val_loss: 0.1150 - val_acc: 0.9716
# Epoch 9/10
# 704/704 [==============================] - 4s 5ms/step - loss: 0.1201 - acc: 0.9560 - val_loss: 0.1394 - val_acc: 0.9432
# Epoch 10/10
# 704/704 [==============================] - 4s 5ms/step - loss: 0.1245 - acc: 0.9446 - val_loss: 0.1557 - val_acc: 0.9659

# %%
## learning curves
import matplotlib.pyplot as plt
epochs = 10
epoch_range = range(1,epochs+1)
#plotting traning & validation accuracy values
history.history.keys()
plt.plot(epoch_range, history.history['acc'])
plt.plot(epoch_range, history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuray')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()
#plotting training & validation loss values
plt.plot(epoch_range, history.history['loss'])
plt.plot(epoch_range, history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc = 'upper left')
plt.show()

# %%
## confusion matrix
#from mlxtend.plotting import plot_confusion_matrix
#from sklearn.metrics import confusion_matrix
#Y_predict = model.predict_classes(X_test)
#conf_mat = confusion_matrix(Y_test, Y_predict)
#plot_confusion_matrix(conf_mat = conf_mat, class_names = Y.classes_, show_normed = False)

# %%
Y_predict = model.predict_classes(X_test)
from sklearn.metrics import confusion_matrix
confusion_Matrix = confusion_matrix(Y_test, Y_predict)
confusion_Matrix
# Out:
# array([[46,  0,  3,  1],
#        [ 2, 53,  0,  0],
#        [ 0,  0, 34,  0],
#        [ 0,  0,  0, 37]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report 
print('\nAccuracy: {:.2f}\n'.format(accuracy_score(Y_test, Y_predict)))
print('\nClassification Report\n')
print(classification_report(Y_test, Y_predict, target_names=['Sitting', 'Walking', 'PushUps', 'Falling']))
# Out:
# Accuracy: 0.97
#
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#      Sitting       0.96      0.92      0.94        50
#      Walking       1.00      0.96      0.98        55
#      PushUps       0.92      1.00      0.96        34
#      Falling       0.97      1.00      0.99        37
#
#     accuracy                           0.97       176
#    macro avg       0.96      0.97      0.97       176
# weighted avg       0.97      0.97      0.97       176
